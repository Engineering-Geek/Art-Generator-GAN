# %%
import matplotlib.pyplot as plt
import torch
from AI_brains import ArtistBrain

# %%
artist = ArtistBrain()
artist.load_state_dict(torch.load("/home/nmelgiri/PycharmProjects/Art-Generator-GAN/Models/Generators/model_2_1.pt")["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
import yaml
doc = yaml.safe_load(open("data.yaml"))
seed_size = doc["Images"]["seed size"]

# %%
artist.eval()
with torch.no_grad():
    result = artist(torch.randn(1, seed_size, 1, 1))

# %%
plt.imshow(result[0].permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
